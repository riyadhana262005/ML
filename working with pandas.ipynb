# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
a1=pd.Series(['one','2','3.5','2+3j','five'],index=[0,1,2,3,4])

# %%
print(a1)
# Out:
# 0     one
# 1       2
# 2     3.5
# 3    2+3j
# 4    five
# dtype: object

# %%
season={"rainy":{1:'nov',2:'dec',3:'jan',4:'feb'},"dry":{1:'sep',2:'aug',
                                                         3:'mar',4:'may'}}

# %%
d=pd.DataFrame(season,columns=["rainy","dry"])

# %%
d
# Out:
#   rainy  dry
# 1   nov  sep
# 2   dec  aug
# 3   jan  mar
# 4   feb  may

# %%
season={"rainy":{1:'nov',2:'dec',3:'jan',4:'feb'},"dry":{1:'sep',2:'aug',
                                                         3:'mar',4:'may'},"win":{1:'may',2:'jan',3:'feb',4:'dec'}}

# %%
d=pd.DataFrame(season,columns=["rainy","dry","win"])

# %%
d
# Out:
#   rainy  dry  win
# 1   nov  sep  may
# 2   dec  aug  jan
# 3   jan  mar  feb
# 4   feb  may  dec

# %%
import numpy as np

# %%
a=pd.DataFrame(np.random.randint(500,1000,size=(25,6)),columns=list('abcdef'))

# %%
'C:/Users/Admin/Documents/semester4 abi.csv'
# Out:
# 'C:/Users/Admin/Documents/semester4 abi.csv'

# %%
a.to_csv('C:/Users/Admin/Documents/semester4 abi.csv')

# %%
d=pd.read_csv('C:/Users/Admin/Documents/semester4 abi.csv')

# %%
print(a)
# Out:
#       a    b    c    d    e    f
# 0   988  520  507  830  798  544
# 1   897  698  924  504  932  764
# 2   777  874  551  588  851  681
# 3   949  904  610  523  618  684
# 4   745  810  559  901  830  747
# 5   780  567  545  735  962  797
# 6   809  899  678  695  714  526
# 7   658  862  656  634  566  524
# 8   951  665  974  924  570  708
# 9   644  676  555  748  701  715
# 10  830  682  671  948  746  720
# 11  836  556  748  694  929  817
# 12  600  650  511  531  828  741
# 13  573  874  794  971  700  881
# 14  828  796  744  530  847  616
# 15  504  954  926  810  990  938
# 16  928  936  776  679  730  542
# 17  600  727  532  999  791  661
# 18  730  683  749  615  560  839
# 19  714  945  696  724  717  506
# 20  972  610  745  689  708  832
# 21  711  888  653  950  880  623
# 22  649  659  585  528  806  711
# 23  508  719  665  888  643  605
# 24  703  516  912  695  951  652

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
data={'movie':['dmd','kodi','veeran','singam'],'rating':[1,2,3,4],'year':[2001,2002,2003,2004]}

# %%
dataframe = pd.DataFrame(data,columns=['movie','rating','year'])

# %%
dataframe
# Out:
#     movie  rating  year
# 0     dmd       1  2001
# 1    kodi       2  2002
# 2  veeran       3  2003
# 3  singam       4  2004

# %%
dataframe=pd.DataFrame(np.random.randint(500,1000,size=(20,3)),columns=list('abc'))

# %%
dataframe
# Out:
#       a    b    c
# 0   757  784  981
# 1   955  632  736
# 2   580  712  931
# 3   971  542  866
# 4   921  706  952
# 5   903  955  910
# 6   765  911  689
# 7   884  991  654
# 8   758  648  682
# 9   931  902  765
# 10  646  546  924
# 11  817  678  922
# 12  848  688  635
# 13  876  746  576
# 14  928  884  858
# 15  922  980  781
# 16  599  635  636
# 17  835  648  721
# 18  825  578  791
# 19  982  749  569

# %% [markdown]
# # data normal;ization

# %%
normalization_df=pd.DataFrame({'x':np.random.randint(-100,100,1000),
                               'y':np.random.randint(-80,80,1000),
                               'z':np.random.randint(-150,150,1000)})

# %%
normalization_df
# Out:
#       x   y    z
# 0    11  30 -150
# 1    -1  78  134
# 2   -27 -53  133
# 3    57  79   54
# 4    70  36  -36
# ..   ..  ..  ...
# 995 -55  54   99
# 996  66 -18   30
# 997  -5 -18   46
# 998   0 -66 -147
# 999  91  34  134
#
# [1000 rows x 3 columns]

# %%
ax =plt.axes(projection='3d')
ax.scatter3D(normalization_df.x,normalization_df.y,normalization_df.z)
plt.figure()

# %%
pip install scikit_learn
# Out:
# Requirement already satisfied: scikit_learn in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from scikit_learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from scikit_learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from scikit_learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\envs\lakshu\lib\site-packages (from scikit_learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import Normalizer

# %%
normal = Normalizer()

# %%
normalization_df = normal.fit_transform(normalization_df)

# %%
normalization_df
# Out:
# array([[ 0.07172405,  0.19561104, -0.9780552 ],
#        [-0.00644947,  0.50305832,  0.8642284 ],
#        [-0.18531879, -0.36377392,  0.91286663],
#        ...,
#        [-0.10070744, -0.36254677,  0.92650842],
#        [ 0.        , -0.4095904 , -0.91226953],
#        [ 0.54982134,  0.20542775,  0.80962703]])

# %%
norm_df = pd.DataFrame(normalization_df,
                       columns=['x1','x2','x3'])

# %%
norm_df
# Out:
#            x1        x2        x3
# 0    0.071724  0.195611 -0.978055
# 1   -0.006449  0.503058  0.864228
# 2   -0.185319 -0.363774  0.912867
# 3    0.511751  0.709269  0.484817
# 4    0.808722  0.415914 -0.415914
# ..        ...       ...       ...
# 995 -0.438362  0.430392  0.789051
# 996  0.883541 -0.240966  0.401610
# 997 -0.100707 -0.362547  0.926508
# 998  0.000000 -0.409590 -0.912270
# 999  0.549821  0.205428  0.809627
#
# [1000 rows x 3 columns]

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(norm_df.x1,norm_df.x2,norm_df.x3)
plt.figure()

# %%
data = {'first score':
